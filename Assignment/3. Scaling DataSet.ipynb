# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt

# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ##Wine DataSet

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ta-verma/DataSets/master/wine.csv")

# %%
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0     1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1     1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2     1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3     1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4     1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
#
# [5 rows x 14 columns]

# %%
print("Mean of Attributes")
print(df.mean())
# Out:
# Mean of Attributes
# Wine                      1.938202
# Alcohol                  13.000618
# Malic.acid                2.336348
# Ash                       2.366517
# Acl                      19.494944
# Mg                       99.741573
# Phenols                   2.295112
# Flavanoids                2.029270
# Nonflavanoid.phenols      0.361854
# Proanth                   1.590899
# Color.int                 5.058090
# Hue                       0.957449
# OD                        2.611685
# Proline                 746.893258
# dtype: float64

# %%
print("Standard Deviation of Attributes")
print(df.std())
# Out:
# Standard Deviation of Attributes
# Wine                      0.775035
# Alcohol                   0.811827
# Malic.acid                1.117146
# Ash                       0.274344
# Acl                       3.339564
# Mg                       14.282484
# Phenols                   0.625851
# Flavanoids                0.998859
# Nonflavanoid.phenols      0.124453
# Proanth                   0.572359
# Color.int                 2.318286
# Hue                       0.228572
# OD                        0.709990
# Proline                 314.907474
# dtype: float64

# %%
#standardization
df2=(df-df.mean())/df.std()

# %%
df2.mean()
# Out:
# Wine                   -1.309814e-15
# Alcohol                 7.823954e-15
# Malic.acid              2.943962e-16
# Ash                    -4.082876e-15
# Acl                    -5.488743e-17
# Mg                     -7.609394e-17
# Phenols                 1.234967e-16
# Flavanoids              9.580351e-16
# Nonflavanoid.phenols   -1.635396e-15
# Proanth                -1.666270e-15
# Color.int              -4.216353e-16
# Hue                     1.657850e-15
# OD                      2.200487e-15
# Proline                -1.341000e-16
# dtype: float64

# %%
df2.std()
# Out:
# Wine                    1.0
# Alcohol                 1.0
# Malic.acid              1.0
# Ash                     1.0
# Acl                     1.0
# Mg                      1.0
# Phenols                 1.0
# Flavanoids              1.0
# Nonflavanoid.phenols    1.0
# Proanth                 1.0
# Color.int               1.0
# Hue                     1.0
# OD                      1.0
# Proline                 1.0
# dtype: float64

# %% [markdown]
# ##Iris Dataset

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/ta-verma/DataSets/master/iris.csv")
df_iris = df3._get_numeric_data()
df_iris.mean()
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64

# %%
df_iris.std()
# Out:
# sepal.length    0.828066
# sepal.width     0.435866
# petal.length    1.765298
# petal.width     0.762238
# dtype: float64

# %%
#standardization
df_iris_std = (df_iris-df_iris.mean())/df_iris.std()

# %%
df_iris_std.mean()
# Out:
# sepal.length   -1.457168e-15
# sepal.width    -1.638319e-15
# petal.length   -1.292300e-15
# petal.width    -5.543714e-16
# dtype: float64

# %%
df_iris_std.std()
# Out:
# sepal.length    1.0
# sepal.width     1.0
# petal.length    1.0
# petal.width     1.0
# dtype: float64
